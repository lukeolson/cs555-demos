# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Problem description

# %% [markdown]
# Here you will set up the problem for
# $$ u_t + c u_x = 0$$
# with periodic BC on the interval [0,1]

# %%
c = 1.0
T = 1.0 / c # end time

# %% [markdown]
# #### Set up the grid

# %% [markdown]
# `hx` is the grid spacing in the `x`-direction
#
# `x` are the grid coordinates
#
# `xx` are really fine grid coordinates

# %%
nx = 100
x = np.linspace(0, 1, nx, endpoint=False)
hx = x[1] - x[0]
xx = np.linspace(0, 1, 100, endpoint=False)
print(hx)
# Out:
# 0.01

# %% [markdown]
# Now define an initial condition

# %%
def square(x):
    u = np.zeros(x.shape)
    u[np.intersect1d(np.where(x>0.4), np.where(x<0.6))] = 1.0
    return u

f = square
fig, ax = plt.subplots(figsize=(8,4))
# TODO: plot the initial condition

# %% [markdown]
# #### Setting time step $h_t$

# %% [markdown]
# Now we need a time step.  Let
# $$ \lambda = a \frac{h_t}{h_x}$$
# and
# $$ h_t = h_x \frac{\lambda}{c}$$
#
# So we first set the parameter $\lambda$

# %%
lmbda = 0.0   # TODO: pick lmbda > 0
ht = hx * lmbda / c
nt = int(T/ht)

print('Setting...')
print(f'lambda = {lmbda}')
print(f'     T = {T}')
print(f'    hx = {hx}')
print('...results in...')
print(f'tsteps = {nt}')
print(f'    ht = {ht}')
# Out:
# /var/folders/6n/rm73m6jj42b58slwfg0zs84c0000gn/T/ipykernel_56434/1281559042.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   nt = int(T/ht)
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[5], line 3
#       1 lmbda = 0.0   # TODO: pick lmbda > 0
#       2 ht = hx * lmbda / c
# ----> 3 nt = int(T/ht)
#       5 print('Setting...')
#       6 print(f'lambda = {lmbda}')
#
# OverflowError: cannot convert float infinity to integer

# %% [markdown]
# Now make an index list, called $J$, so that we can access $J+1$ and $J-1$ easily

# %%
J = np.arange(0, nx)  # all vertices
Jm1 = np.roll(J, 1)
Jp1 = np.roll(J, -1)

# %% [markdown]
# # Run

# %%
err = np.zeros((nt+1, nx))
u = f(x)

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x, u, color='tab:red', ls='-', lw=2)

for tstep in range(1, nt+1):
    # TODO: code ETBS with J and Jm1           

    # TODO: plot the solution at each step
# Out:
#   Cell In[7], line 10
#     # TODO: plot the solution at each step
#                                           ^
# SyntaxError: incomplete input

# %% [markdown]
# #### Check the error?
#
# How would you do this?
